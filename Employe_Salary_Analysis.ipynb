# %% [markdown]
# # **Employee Salary Analysis Dashboards**
#
# ![Dashboard Preview](https://1drv.ms/i/c/6fcf4dcb722f2941/ESgIExfo-XFKox6f5K_lVrMBhlL4TNlxPUk9gtCBLwlssg?e=PZKau2)
#
# ## 📖 Project Overview
# This project presents an analysis of employee salaries across different job roles, experience levels, employment types, and geographical locations. The dashboards were created using **Power BI** and are aimed at providing actionable insights into salary trends. The analysis helps HR departments, recruiters, and job seekers understand salary distributions and how various factors influence compensation.
#
# ---
#
# ## 🔍 Objectives
# - To analyze salary trends based on job roles, experience levels, and employment types.
# - To explore how geographical regions and remote work influence employee salaries.
# - To identify salary disparities by company size and region.
#
# ---
# ## 🛠️ Tools & Technologies
# - **Data Cleaning & Preprocessing**: Microsoft Excel
# - **Data Visualization**: Power BI
# - **Dashboard Hosting**: Local/Shared Workspace (optional)
# - **Version Control**: Git and GitHub
#
# ---
#
# ## 📊 Key Insights
# ### 1. **Employee Salary Overview**:
# - Salary distribution across different job roles (Software Engineer, Data Scientist, HR Manager, etc.).
# - Comparison between full-time and part-time employee salaries.
# - Impact of experience levels (entry-level, mid-level, senior) on salary.
#
# ### 2. **Regional and Remote Work Analysis**:
# - Regional salary disparities, with urban areas having higher salaries than rural regions.
# - Salary comparison between remote and non-remote workers.
# - Influence of company size on employee salaries.
#
# ---
# ## 📁 Project Files
# - ['Cleaned and Preprocessed Data'](https://1drv.ms/x/c/6fcf4dcb722f2941/EVfJpeg_6TVOob0YxjK9GKYBtL0B5dJNnpPuLcZXlhnkKw?e=RsACLz): Cleaned and preprocessed data used for analysis.
# - ['Power BI Dashboard'](https://1drv.ms/u/c/6fcf4dcb722f2941/ERuXPIWTKalCueAfE_evCLkBLicRuDlnQeuPb5yHtoacIg?e=qZGFBK): Power BI dashboard file.
#
# ---
#
# ## 📜 Methodology
# 1. **Data Cleaning**:
#    - Removed null values and duplicates in Excel.
#    - Standardized column names and formats.
#    - Created measures in Power BI for salary analysis, including:
#      - **Max Salary**
#      - **Min Salary**
#      - **Avg Salary**
#      - **Job Categories** (e.g., Software Engineer, Data Scientist, etc.)
# 2. **Data Analysis**:
#    - Calculated key performance indicators (KPIs) such as **max salary**, **min salary**, **average salary**, and **salary by job category**.
#    - Filtered data by region, experience level, and employment type.
#
# 3. **Visualization**:
#    - Created interactive dashboards with bar charts, pie charts, and map visualizations.
#    - Dashboard 1: **Employee Salary Overview** – Shows salary distribution by job title, experience level, and employment type.
#    - Dashboard 2: **Regional and Remote Work Analysis** – Compares salaries by region and employment type (remote vs. non-remote).
#
# ---
#
# ## 🛠️ Features
# - **Interactive Filters**: Allows users to filter data by job title, experience level, and region.
# - **Key Visualizations**:
#   - **Bar Charts**: Visualize salary distribution by job title and experience level.
#   - **Line Chart**: Shows salary trends over time based on experience levels.
#   - **Pie Chart**: Displays salary distribution by region.
#   - **Map Visualization**: Highlights salary differences across regions.
# - **KPIs**: Max Salary, Min Salary, Average Salary, Job Categories.
# ---
#
# ## 📈 Dashboard Preview
# Insert a preview image of your dashboard:
#
# ![Employee Salary Overview](https://1drv.ms/i/c/6fcf4dcb722f2941/ESgIExfo-XFKox6f5K_lVrMBhlL4TNlxPUk9gtCBLwlssg?e=YBVw1r)
#
# ![Regional and Remote Work Analysis](https://1drv.ms/i/c/6fcf4dcb722f2941/EeRnMGKL451Njth4MKdNT28BjOe7ltRFMZL534wnclmUgQ?e=UfZrzu)
#
# ---
#
# ## 📌 Recommendations
# - Focus on regions with significant salary disparities, like urban vs. rural, to help organizations offer competitive compensation.
# - Encourage companies to embrace flexible remote work options, as employees with higher remote work ratios tend to earn better salaries.
# - Identify trends for high-paying job categories to guide recruitment strategies and career advice.
#
# ---
# ## 🚀 How to Use the Dashboard
# 1. Download the ['Power BI Dashboard'](https://1drv.ms/u/c/6fcf4dcb722f2941/ERuXPIWTKalCueAfE_evCLkBLicRuDlnQeuPb5yHtoacIg?e=eHqW9f)
# 2. Open it in **Power BI Desktop**.
# 3. Use the slicers to filter data by job title, experience level, and region.
# 4. Hover over charts for detailed insights.
#
# ---
#
# ## 🤝 Contributing
# Contributions are welcome! If you'd like to contribute, feel free to fork the repository and submit a pull request.
#
# ---
#
# ## 📝 License
# This project is licensed under the [MIT License](LICENSE).
#
# ---
#
# ## 📧 Contact
# If you have any questions or suggestions, feel free to reach out:
# - **Email**: (salmamasthana1998@gmail.com)
# - **LinkedIn**: (www.linkedin.com/in/shaik-salma-masthana-9a4648310)
